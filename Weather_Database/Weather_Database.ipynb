# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                      #    "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mar del plata
# Processing Record 2 of Set 1 | kedrovyy
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | oranjemund
# Processing Record 5 of Set 1 | safaga
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | roald
# Processing Record 8 of Set 1 | adrar
# Processing Record 9 of Set 1 | lasa
# Processing Record 10 of Set 1 | souillac
# Processing Record 11 of Set 1 | nangomba
# Processing Record 12 of Set 1 | sitka
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | phuket
# Processing Record 15 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | smithers
# Processing Record 18 of Set 1 | saint-pierre
# Processing Record 19 of Set 1 | praia
# Processing Record 20 of Set 1 | cap malheureux
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | barranca
# Processing Record 23 of Set 1 | ostersund
# Processing Record 24 of Set 1 | marquette
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | san patricio
# Processing Record 28 of Set 1 | pisco
# Processing Record 29 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 1 | bathsheba
# Processing Record 31 of Set 1 | yerbogachen
# Processing Record 32 of Set 1 | port blair
# Processing Record 33 of Set 1 | kruisfontein
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | san quintin
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | warrington
# Processing Record 38 of Set 1 | chapais
# Processing Record 39 of Set 1 | east london
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | arica
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | sambava
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | maumelle
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | mahibadhoo
# Processing Record 49 of Set 1 | puerto madryn
# Processing Record 50 of Set 1 | kathmandu
# Processing Record 1 of Set 2 | quatre cocos
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | grindavik
# Processing Record 4 of Set 2 | asarganj
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | mount gambier
# Processing Record 7 of Set 2 | tanout
# Processing Record 8 of Set 2 | yagoua
# Processing Record 9 of Set 2 | polessk
# Processing Record 10 of Set 2 | ribeira grande
# Processing Record 11 of Set 2 | bambanglipuro
# Processing Record 12 of Set 2 | beloha
# Processing Record 13 of Set 2 | airai
# Processing Record 14 of Set 2 | rajampet
# Processing Record 15 of Set 2 | clyde river
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | longyearbyen
# Processing Record 18 of Set 2 | ixtapa
# Processing Record 19 of Set 2 | avera
# Processing Record 20 of Set 2 | rawson
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | yuli
# Processing Record 23 of Set 2 | fort nelson
# Processing Record 24 of Set 2 | karratha
# Processing Record 25 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 2 | okhotsk
# Processing Record 27 of Set 2 | sur
# Processing Record 28 of Set 2 | portland
# Processing Record 29 of Set 2 | busselton
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | bardiyah
# Processing Record 32 of Set 2 | fairbanks
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | atambua
# Processing Record 35 of Set 2 | norman wells
# Processing Record 36 of Set 2 | kapaa
# Processing Record 37 of Set 2 | omsukchan
# Processing Record 38 of Set 2 | klaksvik
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | nyurba
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | makung
# City not found. Skipping...
# Processing Record 43 of Set 2 | bluff
# Processing Record 44 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 2 | conde
# Processing Record 46 of Set 2 | dengzhou
# Processing Record 47 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 2 | sobolevo
# Processing Record 49 of Set 2 | havoysund
# Processing Record 50 of Set 2 | hobart
# Processing Record 1 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 3 | payakumbuh
# Processing Record 3 of Set 3 | constitucion
# Processing Record 4 of Set 3 | shellbrook
# Processing Record 5 of Set 3 | svetlogorsk
# Processing Record 6 of Set 3 | bijie
# Processing Record 7 of Set 3 | vila velha
# Processing Record 8 of Set 3 | nushki
# Processing Record 9 of Set 3 | ashoknagar
# Processing Record 10 of Set 3 | shelburne
# Processing Record 11 of Set 3 | kaitangata
# Processing Record 12 of Set 3 | katsuura
# Processing Record 13 of Set 3 | miguelopolis
# Processing Record 14 of Set 3 | porto novo
# Processing Record 15 of Set 3 | batemans bay
# Processing Record 16 of Set 3 | thompson
# Processing Record 17 of Set 3 | kavaratti
# Processing Record 18 of Set 3 | saskylakh
# Processing Record 19 of Set 3 | raudeberg
# Processing Record 20 of Set 3 | sabha
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | suntar
# Processing Record 23 of Set 3 | bonavista
# Processing Record 24 of Set 3 | jining
# Processing Record 25 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 3 | zaysan
# Processing Record 27 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 3 | chuy
# Processing Record 29 of Set 3 | saint-joseph
# Processing Record 30 of Set 3 | namatanai
# Processing Record 31 of Set 3 | khatanga
# Processing Record 32 of Set 3 | ilulissat
# Processing Record 33 of Set 3 | xinmin
# Processing Record 34 of Set 3 | brekstad
# Processing Record 35 of Set 3 | wakkanai
# Processing Record 36 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 3 | charters towers
# Processing Record 38 of Set 3 | sidlaghatta
# Processing Record 39 of Set 3 | lebu
# Processing Record 40 of Set 3 | jamestown
# Processing Record 41 of Set 3 | porto walter
# Processing Record 42 of Set 3 | shimoda
# Processing Record 43 of Set 3 | te anau
# Processing Record 44 of Set 3 | vao
# Processing Record 45 of Set 3 | algeciras
# Processing Record 46 of Set 3 | hithadhoo
# Processing Record 47 of Set 3 | sandy bay
# Processing Record 48 of Set 3 | pontianak
# Processing Record 49 of Set 3 | pangnirtung
# Processing Record 50 of Set 3 | taga dzong
# City not found. Skipping...
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | kodiak
# Processing Record 3 of Set 4 | saint george
# Processing Record 4 of Set 4 | naze
# Processing Record 5 of Set 4 | namibe
# Processing Record 6 of Set 4 | victoria
# Processing Record 7 of Set 4 | esperance
# Processing Record 8 of Set 4 | ahipara
# Processing Record 9 of Set 4 | mao
# Processing Record 10 of Set 4 | manokwari
# Processing Record 11 of Set 4 | arkhangelos
# City not found. Skipping...
# Processing Record 12 of Set 4 | kaniama
# Processing Record 13 of Set 4 | belmonte
# Processing Record 14 of Set 4 | moose factory
# Processing Record 15 of Set 4 | arraial do cabo
# Processing Record 16 of Set 4 | hermanus
# Processing Record 17 of Set 4 | springfield
# Processing Record 18 of Set 4 | coahuayana
# Processing Record 19 of Set 4 | nikolskoye
# Processing Record 20 of Set 4 | saint anthony
# Processing Record 21 of Set 4 | ormara
# Processing Record 22 of Set 4 | port-gentil
# Processing Record 23 of Set 4 | beringovskiy
# Processing Record 24 of Set 4 | pingshan
# Processing Record 25 of Set 4 | samarai
# Processing Record 26 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 4 | atuona
# Processing Record 28 of Set 4 | hendijan
# City not found. Skipping...
# Processing Record 29 of Set 4 | cidreira
# Processing Record 30 of Set 4 | eenhana
# Processing Record 31 of Set 4 | canon city
# Processing Record 32 of Set 4 | avarua
# Processing Record 33 of Set 4 | alyangula
# Processing Record 34 of Set 4 | cicero
# Processing Record 35 of Set 4 | talnakh
# Processing Record 36 of Set 4 | martapura
# Processing Record 37 of Set 4 | mahebourg
# Processing Record 38 of Set 4 | geraldton
# Processing Record 39 of Set 4 | ouallam
# Processing Record 40 of Set 4 | rincon
# Processing Record 41 of Set 4 | sao filipe
# Processing Record 42 of Set 4 | torbay
# Processing Record 43 of Set 4 | daoukro
# Processing Record 44 of Set 4 | strezhevoy
# Processing Record 45 of Set 4 | faanui
# Processing Record 46 of Set 4 | horta
# Processing Record 47 of Set 4 | manadhoo
# Processing Record 48 of Set 4 | bullhead city
# Processing Record 49 of Set 4 | vallenar
# Processing Record 50 of Set 4 | tromso
# Processing Record 1 of Set 5 | hami
# Processing Record 2 of Set 5 | marsabit
# Processing Record 3 of Set 5 | muros
# Processing Record 4 of Set 5 | farah
# Processing Record 5 of Set 5 | praya
# Processing Record 6 of Set 5 | narsaq
# Processing Record 7 of Set 5 | kantang
# Processing Record 8 of Set 5 | iberia
# Processing Record 9 of Set 5 | eagle pass
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | puerto escondido
# Processing Record 12 of Set 5 | yumen
# Processing Record 13 of Set 5 | cape town
# Processing Record 14 of Set 5 | margate
# Processing Record 15 of Set 5 | sakakah
# Processing Record 16 of Set 5 | japura
# Processing Record 17 of Set 5 | alta floresta
# Processing Record 18 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 19 of Set 5 | concordia
# Processing Record 20 of Set 5 | mugur-aksy
# Processing Record 21 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 22 of Set 5 | ginir
# Processing Record 23 of Set 5 | qaanaaq
# Processing Record 24 of Set 5 | padang
# Processing Record 25 of Set 5 | kudahuvadhoo
# Processing Record 26 of Set 5 | urucara
# Processing Record 27 of Set 5 | pacora
# Processing Record 28 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 5 | upernavik
# Processing Record 30 of Set 5 | attur
# Processing Record 31 of Set 5 | calvinia
# Processing Record 32 of Set 5 | stawell
# Processing Record 33 of Set 5 | brae
# Processing Record 34 of Set 5 | almaznyy
# Processing Record 35 of Set 5 | laguna
# Processing Record 36 of Set 5 | castro
# Processing Record 37 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 5 | coquimbo
# Processing Record 39 of Set 5 | codrington
# Processing Record 40 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 41 of Set 5 | port lincoln
# Processing Record 42 of Set 5 | puri
# Processing Record 43 of Set 5 | coruripe
# Processing Record 44 of Set 5 | abu kamal
# Processing Record 45 of Set 5 | humaita
# Processing Record 46 of Set 5 | ust-kut
# Processing Record 47 of Set 5 | ponta do sol
# Processing Record 48 of Set 5 | imeni poliny osipenko
# Processing Record 49 of Set 5 | nanortalik
# Processing Record 50 of Set 5 | keuruu
# Processing Record 1 of Set 6 | jilib
# Processing Record 2 of Set 6 | tasiilaq
# Processing Record 3 of Set 6 | isangel
# Processing Record 4 of Set 6 | bengkulu
# Processing Record 5 of Set 6 | muli
# Processing Record 6 of Set 6 | kamenka
# Processing Record 7 of Set 6 | severo-kurilsk
# Processing Record 8 of Set 6 | olafsvik
# Processing Record 9 of Set 6 | high level
# Processing Record 10 of Set 6 | anadyr
# Processing Record 11 of Set 6 | labelle
# Processing Record 12 of Set 6 | cabo san lucas
# Processing Record 13 of Set 6 | dingle
# Processing Record 14 of Set 6 | vilhena
# Processing Record 15 of Set 6 | paita
# Processing Record 16 of Set 6 | faya
# Processing Record 17 of Set 6 | alofi
# Processing Record 18 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 6 | dargaville
# Processing Record 20 of Set 6 | salamiyah
# Processing Record 21 of Set 6 | hasaki
# Processing Record 22 of Set 6 | segamat
# Processing Record 23 of Set 6 | tarko-sale
# Processing Record 24 of Set 6 | hervey bay
# Processing Record 25 of Set 6 | kiama
# Processing Record 26 of Set 6 | guane
# Processing Record 27 of Set 6 | port hardy
# Processing Record 28 of Set 6 | carnarvon
# Processing Record 29 of Set 6 | zhigansk
# Processing Record 30 of Set 6 | evensk
# Processing Record 31 of Set 6 | hamilton
# Processing Record 32 of Set 6 | yelanskiy
# Processing Record 33 of Set 6 | sao miguel do araguaia
# Processing Record 34 of Set 6 | galesong
# Processing Record 35 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 36 of Set 6 | morant bay
# Processing Record 37 of Set 6 | san policarpo
# Processing Record 38 of Set 6 | shihezi
# Processing Record 39 of Set 6 | mocorito
# Processing Record 40 of Set 6 | port elizabeth
# Processing Record 41 of Set 6 | fortuna
# Processing Record 42 of Set 6 | erenhot
# Processing Record 43 of Set 6 | biloela
# Processing Record 44 of Set 6 | hofn
# Processing Record 45 of Set 6 | roebourne
# Processing Record 46 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 6 | lakatoro
# Processing Record 48 of Set 6 | jiangyou
# Processing Record 49 of Set 6 | palmer
# Processing Record 50 of Set 6 | nador
# Processing Record 1 of Set 7 | morondava
# Processing Record 2 of Set 7 | puerto quijarro
# Processing Record 3 of Set 7 | melbu
# Processing Record 4 of Set 7 | lorengau
# Processing Record 5 of Set 7 | moss vale
# Processing Record 6 of Set 7 | la ronge
# Processing Record 7 of Set 7 | nedjo
# Processing Record 8 of Set 7 | ketchikan
# Processing Record 9 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 10 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 7 | inirida
# Processing Record 12 of Set 7 | tuatapere
# Processing Record 13 of Set 7 | ushtobe
# Processing Record 14 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 15 of Set 7 | columbia
# Processing Record 16 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 7 | tambopata
# Processing Record 18 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 7 | cuenca
# Processing Record 20 of Set 7 | tall kayf
# Processing Record 21 of Set 7 | thaton
# Processing Record 22 of Set 7 | brownfield
# Processing Record 23 of Set 7 | peterhead
# Processing Record 24 of Set 7 | guozhen
# Processing Record 25 of Set 7 | balkanabat
# Processing Record 26 of Set 7 | hambantota
# Processing Record 27 of Set 7 | banda aceh
# Processing Record 28 of Set 7 | newport
# Processing Record 29 of Set 7 | minnedosa
# Processing Record 30 of Set 7 | husavik
# Processing Record 31 of Set 7 | onoda
# Processing Record 32 of Set 7 | portsmouth
# Processing Record 33 of Set 7 | ouadda
# Processing Record 34 of Set 7 | aurdal
# Processing Record 35 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 36 of Set 7 | kahului
# Processing Record 37 of Set 7 | bethel
# Processing Record 38 of Set 7 | zyryanka
# Processing Record 39 of Set 7 | necochea
# Processing Record 40 of Set 7 | maxixe
# Processing Record 41 of Set 7 | bandarbeyla
# Processing Record 42 of Set 7 | watertown
# Processing Record 43 of Set 7 | hirara
# Processing Record 44 of Set 7 | port keats
# Processing Record 45 of Set 7 | sept-iles
# Processing Record 46 of Set 7 | saldanha
# Processing Record 47 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 7 | panzhihua
# Processing Record 49 of Set 7 | kozhva
# Processing Record 50 of Set 7 | koryazhma
# Processing Record 1 of Set 8 | liusha
# Processing Record 2 of Set 8 | luanda
# Processing Record 3 of Set 8 | aklavik
# Processing Record 4 of Set 8 | miloi
# City not found. Skipping...
# Processing Record 5 of Set 8 | saint-augustin
# Processing Record 6 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 8 | houma
# Processing Record 8 of Set 8 | simpang rengam
# City not found. Skipping...
# Processing Record 9 of Set 8 | xining
# Processing Record 10 of Set 8 | caravelas
# Processing Record 11 of Set 8 | benghazi
# Processing Record 12 of Set 8 | sudzha
# Processing Record 13 of Set 8 | alice springs
# Processing Record 14 of Set 8 | kalmunai
# Processing Record 15 of Set 8 | haimen
# Processing Record 16 of Set 8 | presidente medici
# Processing Record 17 of Set 8 | azle
# Processing Record 18 of Set 8 | desnogorsk
# Processing Record 19 of Set 8 | kribi
# Processing Record 20 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 21 of Set 8 | vanimo
# Processing Record 22 of Set 8 | letpadan
# Processing Record 23 of Set 8 | mooi river
# City not found. Skipping...
# Processing Record 24 of Set 8 | tazovskiy
# Processing Record 25 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 26 of Set 8 | gunnedah
# Processing Record 27 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 8 | tura
# Processing Record 29 of Set 8 | veraval
# Processing Record 30 of Set 8 | merritt
# Processing Record 31 of Set 8 | handan
# Processing Record 32 of Set 8 | matagami
# Processing Record 33 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 34 of Set 8 | burnie
# Processing Record 35 of Set 8 | samana
# Processing Record 36 of Set 8 | ola
# Processing Record 37 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 8 | shcholkine
# City not found. Skipping...
# Processing Record 39 of Set 8 | clarence town
# Processing Record 40 of Set 8 | iralaya
# Processing Record 41 of Set 8 | dongsheng
# Processing Record 42 of Set 8 | grand baie
# Processing Record 43 of Set 8 | birjand
# Processing Record 44 of Set 8 | bernalillo
# Processing Record 45 of Set 8 | touros
# Processing Record 46 of Set 8 | mezen
# Processing Record 47 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 48 of Set 8 | hualmay
# Processing Record 49 of Set 8 | bogatic
# Processing Record 50 of Set 8 | salta
# Processing Record 1 of Set 9 | zhigalovo
# Processing Record 2 of Set 9 | yashan
# Processing Record 3 of Set 9 | new richmond
# Processing Record 4 of Set 9 | paamiut
# Processing Record 5 of Set 9 | mehamn
# Processing Record 6 of Set 9 | hay river
# Processing Record 7 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 9 of Set 9 | sorland
# Processing Record 10 of Set 9 | nouadhibou
# Processing Record 11 of Set 9 | moron
# Processing Record 12 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 9 | cosala
# Processing Record 14 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 9 | maumere
# Processing Record 16 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 9 | denpasar
# Processing Record 18 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 9 | sueyoshi
# Processing Record 20 of Set 9 | qaqortoq
# Processing Record 21 of Set 9 | alekseyevsk
# Processing Record 22 of Set 9 | rabo de peixe
# Processing Record 23 of Set 9 | filingue
# Processing Record 24 of Set 9 | cayenne
# Processing Record 25 of Set 9 | buala
# Processing Record 26 of Set 9 | agadir
# Processing Record 27 of Set 9 | jieshi
# Processing Record 28 of Set 9 | umea
# Processing Record 29 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 9 | fare
# Processing Record 31 of Set 9 | atar
# Processing Record 32 of Set 9 | aykhal
# Processing Record 33 of Set 9 | kisanga
# Processing Record 34 of Set 9 | cedral
# Processing Record 35 of Set 9 | dauphin
# Processing Record 36 of Set 9 | richards bay
# Processing Record 37 of Set 9 | lompoc
# Processing Record 38 of Set 9 | bilibino
# Processing Record 39 of Set 9 | solnechnyy
# Processing Record 40 of Set 9 | katobu
# Processing Record 41 of Set 9 | pathein
# Processing Record 42 of Set 9 | tiksi
# Processing Record 43 of Set 9 | nikolayevka
# Processing Record 44 of Set 9 | tarata
# Processing Record 45 of Set 9 | yala
# Processing Record 46 of Set 9 | moree
# Processing Record 47 of Set 9 | mocuba
# Processing Record 48 of Set 9 | altos
# Processing Record 49 of Set 9 | deputatskiy
# Processing Record 50 of Set 9 | garissa
# Processing Record 1 of Set 10 | slyudyanka
# Processing Record 2 of Set 10 | turochak
# Processing Record 3 of Set 10 | ostrovnoy
# Processing Record 4 of Set 10 | landeck
# Processing Record 5 of Set 10 | whitehorse
# Processing Record 6 of Set 10 | labuhan
# Processing Record 7 of Set 10 | nola
# Processing Record 8 of Set 10 | karaton
# Processing Record 9 of Set 10 | tsumeb
# Processing Record 10 of Set 10 | comodoro rivadavia
# Processing Record 11 of Set 10 | komsomolskiy
# Processing Record 12 of Set 10 | camrose
# Processing Record 13 of Set 10 | ulaangom
# Processing Record 14 of Set 10 | westport
# Processing Record 15 of Set 10 | boyolangu
# Processing Record 16 of Set 10 | santa isabel
# Processing Record 17 of Set 10 | ermelo
# Processing Record 18 of Set 10 | xihe
# Processing Record 19 of Set 10 | lata
# Processing Record 20 of Set 10 | zeya
# Processing Record 21 of Set 10 | ongandjera
# Processing Record 22 of Set 10 | port moresby
# Processing Record 23 of Set 10 | khandyga
# Processing Record 24 of Set 10 | amga
# Processing Record 25 of Set 10 | kenai
# Processing Record 26 of Set 10 | khartoum
# Processing Record 27 of Set 10 | nishiwaki
# Processing Record 28 of Set 10 | sao joao da barra
# Processing Record 29 of Set 10 | havre-saint-pierre
# Processing Record 30 of Set 10 | sokol
# Processing Record 31 of Set 10 | gat
# Processing Record 32 of Set 10 | beyneu
# Processing Record 33 of Set 10 | punahana
# Processing Record 34 of Set 10 | wentzville
# Processing Record 35 of Set 10 | carmelo
# Processing Record 36 of Set 10 | jefferson city
# Processing Record 37 of Set 10 | hue
# Processing Record 38 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 39 of Set 10 | luderitz
# Processing Record 40 of Set 10 | chaa-khol
# City not found. Skipping...
# Processing Record 41 of Set 10 | san matias
# Processing Record 42 of Set 10 | ponta delgada
# Processing Record 43 of Set 10 | gondanglegi
# Processing Record 44 of Set 10 | praia da vitoria
# Processing Record 45 of Set 10 | diffa
# Processing Record 46 of Set 10 | meadow lake
# Processing Record 47 of Set 10 | swan hill
# Processing Record 48 of Set 10 | yulara
# Processing Record 49 of Set 10 | koumac
# Processing Record 50 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 1 of Set 11 | peniche
# Processing Record 2 of Set 11 | buraydah
# Processing Record 3 of Set 11 | rock springs
# Processing Record 4 of Set 11 | bartica
# Processing Record 5 of Set 11 | zemio
# Processing Record 6 of Set 11 | cockburn town
# Processing Record 7 of Set 11 | puerto cortes
# City not found. Skipping...
# Processing Record 8 of Set 11 | tolbazy
# Processing Record 9 of Set 11 | roseburg
# Processing Record 10 of Set 11 | jatiroto
# Processing Record 11 of Set 11 | harper
# Processing Record 12 of Set 11 | port dickson
# Processing Record 13 of Set 11 | nioki
# Processing Record 14 of Set 11 | jacareacanga
# Processing Record 15 of Set 11 | pondicherry
# Processing Record 16 of Set 11 | litovko
# Processing Record 17 of Set 11 | natchez
# Processing Record 18 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 11 | kawai
# Processing Record 20 of Set 11 | sile
# Processing Record 21 of Set 11 | neiafu
# Processing Record 22 of Set 11 | bonoua
# Processing Record 23 of Set 11 | chapayevka
# Processing Record 24 of Set 11 | sydney
# Processing Record 25 of Set 11 | dali
# Processing Record 26 of Set 11 | prince rupert
# Processing Record 27 of Set 11 | chabahar
# Processing Record 28 of Set 11 | lavrentiya
# Processing Record 29 of Set 11 | sangar
# Processing Record 30 of Set 11 | buchanan
# Processing Record 31 of Set 11 | san vicente de canete
# Processing Record 32 of Set 11 | flinders
# Processing Record 33 of Set 11 | zabkowice slaskie
# Processing Record 34 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 11 | mian channun
# Processing Record 36 of Set 11 | nanzhang
# Processing Record 37 of Set 11 | wa
# City not found. Skipping...
# Processing Record 38 of Set 11 | waw
# Processing Record 39 of Set 11 | malyye derbety
# Processing Record 40 of Set 11 | jaltenango
# Processing Record 41 of Set 11 | turukhansk
# Processing Record 42 of Set 11 | griffith
# Processing Record 43 of Set 11 | hobyo
# Processing Record 44 of Set 11 | valley city
# Processing Record 45 of Set 11 | saint-georges
# Processing Record 46 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 11 | ukiah
# Processing Record 48 of Set 11 | zhengjiatun
# Processing Record 49 of Set 11 | saint-paul
# Processing Record 50 of Set 11 | mayo
# Processing Record 1 of Set 12 | pauini
# Processing Record 2 of Set 12 | mount isa
# Processing Record 3 of Set 12 | viedma
# Processing Record 4 of Set 12 | barra
# Processing Record 5 of Set 12 | monster
# Processing Record 6 of Set 12 | linxia
# Processing Record 7 of Set 12 | lewiston
# Processing Record 8 of Set 12 | qasigiannguit
# Processing Record 9 of Set 12 | corabia
# Processing Record 10 of Set 12 | ancud
# Processing Record 11 of Set 12 | laurel
# Processing Record 12 of Set 12 | akyab
# Processing Record 13 of Set 12 | aktau
# Processing Record 14 of Set 12 | doha
# Processing Record 15 of Set 12 | nsoko
# Processing Record 16 of Set 12 | bilma
# Processing Record 17 of Set 12 | yemtsa
# Processing Record 18 of Set 12 | zhitikara
# City not found. Skipping...
# Processing Record 19 of Set 12 | reno
# Processing Record 20 of Set 12 | carutapera
# Processing Record 21 of Set 12 | belokurikha
# Processing Record 22 of Set 12 | yichang
# Processing Record 23 of Set 12 | broken hill
# Processing Record 24 of Set 12 | glens falls
# Processing Record 25 of Set 12 | les cayes
# Processing Record 26 of Set 12 | svobodnyy
# Processing Record 27 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 28 of Set 12 | ploemeur
# Processing Record 29 of Set 12 | bud
# Processing Record 30 of Set 12 | sibolga
# Processing Record 31 of Set 12 | muravlenko
# Processing Record 32 of Set 12 | valjala
# City not found. Skipping...
# Processing Record 33 of Set 12 | kutum
# Processing Record 34 of Set 12 | dunedin
# Processing Record 35 of Set 12 | virginia beach
# Processing Record 36 of Set 12 | bereda
# Processing Record 37 of Set 12 | kargapolye
# City not found. Skipping...
# Processing Record 38 of Set 12 | rubtsovsk
# Processing Record 39 of Set 12 | bayan
# Processing Record 40 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 41 of Set 12 | alappuzha
# Processing Record 42 of Set 12 | moen
# Processing Record 43 of Set 12 | linhares
# Processing Record 44 of Set 12 | vostok
# Processing Record 45 of Set 12 | yatou
# Processing Record 46 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 47 of Set 12 | dubbo
# Processing Record 48 of Set 12 | arlit
# Processing Record 49 of Set 12 | princeton
# Processing Record 50 of Set 12 | loandjili
# Processing Record 1 of Set 13 | vanavara
# Processing Record 2 of Set 13 | tautira
# Processing Record 3 of Set 13 | honiara
# Processing Record 4 of Set 13 | nowy targ
# Processing Record 5 of Set 13 | leshukonskoye
# Processing Record 6 of Set 13 | menongue
# Processing Record 7 of Set 13 | haines junction
# Processing Record 8 of Set 13 | maroua
# Processing Record 9 of Set 13 | lima
# Processing Record 10 of Set 13 | poum
# Processing Record 11 of Set 13 | bendigo
# Processing Record 12 of Set 13 | guilin
# Processing Record 13 of Set 13 | taoudenni
# Processing Record 14 of Set 13 | paris
# Processing Record 15 of Set 13 | santa fe
# Processing Record 16 of Set 13 | sinnamary
# Processing Record 17 of Set 13 | doctor arroyo
# Processing Record 18 of Set 13 | scarborough
# Processing Record 19 of Set 13 | pandan
# Processing Record 20 of Set 13 | bratsk
# Processing Record 21 of Set 13 | nabire
# Processing Record 22 of Set 13 | lake city
# Processing Record 23 of Set 13 | balabac
# Processing Record 24 of Set 13 | malkara
# Processing Record 25 of Set 13 | stephenville crossing
# Processing Record 26 of Set 13 | san cristobal
# Processing Record 27 of Set 13 | caconda
# Processing Record 28 of Set 13 | quelimane
# Processing Record 29 of Set 13 | college
# Processing Record 30 of Set 13 | lieksa
# Processing Record 31 of Set 13 | high rock
# Processing Record 32 of Set 13 | gorontalo
# Processing Record 33 of Set 13 | port perry
# Processing Record 34 of Set 13 | sao felix do xingu
# Processing Record 35 of Set 13 | noyabrsk
# Processing Record 36 of Set 13 | wanning
# Processing Record 37 of Set 13 | catamarca
# Processing Record 38 of Set 13 | kandi
# Processing Record 39 of Set 13 | catuday
# Processing Record 40 of Set 13 | matara
# Processing Record 41 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 42 of Set 13 | sunndalsora
# Processing Record 43 of Set 13 | deoranian
# Processing Record 44 of Set 13 | marzuq
# Processing Record 45 of Set 13 | coihueco
# Processing Record 46 of Set 13 | yenagoa
# Processing Record 47 of Set 13 | west lafayette
# Processing Record 48 of Set 13 | coihaique
# Processing Record 49 of Set 13 | piet retief
# Processing Record 50 of Set 13 | quballat
# Processing Record 1 of Set 14 | baker city
# Processing Record 2 of Set 14 | bichena
# Processing Record 3 of Set 14 | sharkan
# Processing Record 4 of Set 14 | castro verde
# Processing Record 5 of Set 14 | agadez
# Processing Record 6 of Set 14 | sumbe
# Processing Record 7 of Set 14 | sooke
# Processing Record 8 of Set 14 | verkhnevilyuysk
# Processing Record 9 of Set 14 | upington
# Processing Record 10 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 11 of Set 14 | berea
# Processing Record 12 of Set 14 | jalu
# Processing Record 13 of Set 14 | benalla
# Processing Record 14 of Set 14 | nuuk
# Processing Record 15 of Set 14 | tezu
# Processing Record 16 of Set 14 | villa union
# Processing Record 17 of Set 14 | dawlatabad
# Processing Record 18 of Set 14 | ternate
# Processing Record 19 of Set 14 | pindiga
# Processing Record 20 of Set 14 | metro
# Processing Record 21 of Set 14 | manicore
# Processing Record 22 of Set 14 | ust-maya
# Processing Record 23 of Set 14 | santa vitoria
# Processing Record 24 of Set 14 | kodinsk
# Processing Record 25 of Set 14 | noumea
# Processing Record 26 of Set 14 | zhanaozen
# Processing Record 27 of Set 14 | nambiyur
# Processing Record 28 of Set 14 | takoradi
# Processing Record 29 of Set 14 | gigmoto
# Processing Record 30 of Set 14 | erzin
# Processing Record 31 of Set 14 | abnub
# Processing Record 32 of Set 14 | camacha
# Processing Record 33 of Set 14 | liling
# Processing Record 34 of Set 14 | iqaluit
# Processing Record 35 of Set 14 | jonesboro
# Processing Record 36 of Set 14 | kirakira
# Processing Record 37 of Set 14 | cabinda
# Processing Record 38 of Set 14 | lucelia
# Processing Record 39 of Set 14 | mitsamiouli
# Processing Record 40 of Set 14 | cape canaveral
# Processing Record 41 of Set 14 | umm lajj
# Processing Record 42 of Set 14 | phumi samraong
# City not found. Skipping...
# Processing Record 43 of Set 14 | foam lake
# Processing Record 44 of Set 14 | gravdal
# Processing Record 45 of Set 14 | lagoa
# Processing Record 46 of Set 14 | visby
# Processing Record 47 of Set 14 | seymchan
# Processing Record 48 of Set 14 | tabas
# Processing Record 49 of Set 14 | henties bay
# Processing Record 50 of Set 14 | ehingen
# Processing Record 1 of Set 15 | ocampo
# Processing Record 2 of Set 15 | cao bang
# Processing Record 3 of Set 15 | nanyang
# Processing Record 4 of Set 15 | mecca
# Processing Record 5 of Set 15 | de-kastri
# Processing Record 6 of Set 15 | ampanihy
# Processing Record 7 of Set 15 | mildura
# Processing Record 8 of Set 15 | bordei verde
# Processing Record 9 of Set 15 | springdale
# Processing Record 10 of Set 15 | duluth
# Processing Record 11 of Set 15 | talara
# Processing Record 12 of Set 15 | ossora
# Processing Record 13 of Set 15 | kon tum
# Processing Record 14 of Set 15 | rundu
# Processing Record 15 of Set 15 | roros
# Processing Record 16 of Set 15 | kamyshlov
# Processing Record 17 of Set 15 | katherine
# Processing Record 18 of Set 15 | venice
# Processing Record 19 of Set 15 | ndele
# Processing Record 20 of Set 15 | bowen
# Processing Record 21 of Set 15 | bucerias
# Processing Record 22 of Set 15 | sioux lookout
# Processing Record 23 of Set 15 | flin flon
# Processing Record 24 of Set 15 | charagua
# Processing Record 25 of Set 15 | igrim
# Processing Record 26 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 27 of Set 15 | tiznit
# Processing Record 28 of Set 15 | dehui
# Processing Record 29 of Set 15 | koutsouras
# Processing Record 30 of Set 15 | sorong
# Processing Record 31 of Set 15 | daigo
# Processing Record 32 of Set 15 | chute-aux-outardes
# Processing Record 33 of Set 15 | villa carlos paz
# Processing Record 34 of Set 15 | sabang
# Processing Record 35 of Set 15 | hargeysa
# Processing Record 36 of Set 15 | bubaque
# Processing Record 37 of Set 15 | zlobin
# Processing Record 38 of Set 15 | garden city
# Processing Record 39 of Set 15 | la romana
# Processing Record 40 of Set 15 | altay
# Processing Record 41 of Set 15 | kununurra
# Processing Record 42 of Set 15 | tigil
# Processing Record 43 of Set 15 | aksu
# Processing Record 44 of Set 15 | magadi
# Processing Record 45 of Set 15 | broome
# Processing Record 46 of Set 15 | rio grande
# Processing Record 47 of Set 15 | mascote
# Processing Record 48 of Set 15 | beni mazar
# Processing Record 49 of Set 15 | lafayette
# Processing Record 50 of Set 15 | half moon bay
# Processing Record 1 of Set 16 | vila
# Processing Record 2 of Set 16 | yefira
# City not found. Skipping...
# Processing Record 3 of Set 16 | gaogou
# Processing Record 4 of Set 16 | abiy adi
# City not found. Skipping...
# Processing Record 5 of Set 16 | aksarka
# Processing Record 6 of Set 16 | zhaoyuan
# Processing Record 7 of Set 16 | missoula
# Processing Record 8 of Set 16 | asau
# Processing Record 9 of Set 16 | grand-lahou
# Processing Record 10 of Set 16 | dasoguz
# Processing Record 11 of Set 16 | tambul
# City not found. Skipping...
# Processing Record 12 of Set 16 | khurai
# Processing Record 13 of Set 16 | salisbury
# Processing Record 14 of Set 16 | de aar
# Processing Record 15 of Set 16 | tawnat
# City not found. Skipping...
# Processing Record 16 of Set 16 | asfi
# Processing Record 17 of Set 16 | mandal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Mar Del Plata -38.00  -57.56     69.01        93          91        6.93
# 1       Kedrovyy  56.17   91.82    -25.60        67          78        4.47
# 2        Rikitea -23.12 -134.97     78.76        78         100       14.09
# 3     Oranjemund -28.55   16.43     66.07        68         100       13.56
# 4         Safaga  26.73   33.94     64.40        59          50        9.17
#
#   Country Current Description
# 0      AR     overcast clouds
# 1      RU                mist
# 2      PF       moderate rain
# 3      NA     overcast clouds
# 4      EG    scattered clouds

# %%
#Re-order columns --City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed
new_column_order = ["City", "Country",  "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mar Del Plata      AR -38.00  -57.56     69.01        93          91
# 1       Kedrovyy      RU  56.17   91.82    -25.60        67          78
# 2        Rikitea      PF -23.12 -134.97     78.76        78         100
# 3     Oranjemund      NA -28.55   16.43     66.07        68         100
# 4         Safaga      EG  26.73   33.94     64.40        59          50
#
#    Wind Speed Current Description
# 0        6.93     overcast clouds
# 1        4.47                mist
# 2       14.09       moderate rain
# 3       13.56     overcast clouds
# 4        9.17    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
